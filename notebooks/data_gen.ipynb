# %%
import os
import pandas as pd
from PIL import Image, ImageSequence, GifImagePlugin
import imagehash
from io import BytesIO

import requests
from pathlib import Path

# %%
# setting up necessary directory names

DATA_PATH = Path("../data")
SPRITE_PATH = Path("sprite")
ARTWORK_PATH = Path("artwork")
MASK_PATH = Path("masks")
DATALOADER_CSV_PATH = DATA_PATH / Path("data.csv")
# DATA_PATH / SPRITE_PATH

# %%
# Some information for streamlining api access
api_url = "https://pokeapi.co/api/v2/pokemon/"

# Create a list of roman numerals for generations to pull sprites from
# There are no more pixel art sprites after gen v  
# and the art style changes between gen ii and iii
version_key = "versions"
roman_numerals = ["iii", "iv", "v"]
generations = [f"generation-{i}" for i in roman_numerals]
game_names = [["emerald", "firered-leafgreen", "ruby-sapphire"], ["platinum", "diamond-pearl", "heartgold-soulsilver"], ["black-white"]]
generations_to_games = {gen: games for gen, games in zip(generations, game_names)}

animation_gen = "generation-v"
anim_game = "black-white"
anim_key = "animated"

sprite_keys = ["front_default", "front_shiny", "front_female", "front_shiny_female"]
artwork_keys = ["front_default", "front_shiny"]

save_animations = False

# %%
# read in df with pokemon
CSV_PATH = Path("../pokemon.csv")
poke_df = pd.read_csv(CSV_PATH)
poke_df = poke_df.drop(columns=['Unnamed: 0'])


poke_df.tail()
# Out:
#          id      name  height  weight         ability_1         ability_3  \
# 1274  10267  koraidon      35    3030  orichalcum-pulse  orichalcum-pulse
# 1275  10268  miraidon      28    2400     hadron-engine     hadron-engine
# 1276  10269  miraidon      28    2400     hadron-engine     hadron-engine
# 1277  10270  miraidon      28    2400     hadron-engine     hadron-engine
# 1278  10271  miraidon      28    2400     hadron-engine     hadron-engine
#
#       forms_switchable  gender_rate genera  has_gender_differences  ...  \
# 1274             False           -1    NaN                   False  ...
# 1275             False           -1    NaN                   False  ...
# 1276             False           -1    NaN                   False  ...
# 1277             False           -1    NaN                   False  ...
# 1278             False           -1    NaN                   False  ...
#
#       flavor_text_17  ability_2  flavor_text_18 flavor_text_19 flavor_text_20  \
# 1274             NaN        NaN             NaN            NaN            NaN
# 1275             NaN        NaN             NaN            NaN            NaN
# 1276             NaN        NaN             NaN            NaN            NaN
# 1277             NaN        NaN             NaN            NaN            NaN
# 1278             NaN        NaN             NaN            NaN            NaN
#
#      flavor_text_21 flavor_text_22 flavor_text_23 flavor_text_24  \
# 1274            NaN            NaN            NaN            NaN
# 1275            NaN            NaN            NaN            NaN
# 1276            NaN            NaN            NaN            NaN
# 1277            NaN            NaN            NaN            NaN
# 1278            NaN            NaN            NaN            NaN
#
#      flavor_text_25
# 1274            NaN
# 1275            NaN
# 1276            NaN
# 1277            NaN
# 1278            NaN
#
# [5 rows x 61 columns]

# %%
# create directories where pokemon images will be written
if not os.path.exists(DATA_PATH / SPRITE_PATH):
    os.makedirs(DATA_PATH / SPRITE_PATH)

if not os.path.exists(DATA_PATH / ARTWORK_PATH):
    os.makedirs(DATA_PATH / ARTWORK_PATH)

if not os.path.exists(DATA_PATH / MASK_PATH):
    os.makedirs(DATA_PATH / MASK_PATH)

# %%
# NOTE: Remember to drop "RGBA" mode pngs as these are sprite representations of 3d pokemon models

def get_sprite_links(ids: list[int], base_url: str):
    result = {}
    for id in ids:
        print(f"Processing id: {id}")
        resp = requests.get(base_url + str(id))

        if resp.status_code == 200:
            data = resp.json()
            result[id] = data["sprites"]
        else:
            print(f"Retrieving id {id} failed!")
    
    return result

def extract_pertinent_links(link_dict):
    result = {}
    for id, data in link_dict.items():
        links = {}
        links["default"] = {key: data[key] for key in sprite_keys}
        links["artwork"] = {key: data["other"]["official-artwork"][key] for key in artwork_keys}

        # get sprites for all prior versions
        for gen in generations:
            curr_gen = data["versions"][gen]
            links[gen] = {game: {key: curr_gen[game][key]  
                                 for key in sprite_keys if key in curr_gen[game]} 
                          for game in generations_to_games[gen]}

        # get animations from gen v
        anim_data = data["versions"][animation_gen][anim_game][anim_key]
        links["animation"] = {key: anim_data[key] for key in sprite_keys}

        result[id] = links

    return result

# %%
poke_ids = [i for i in poke_df["id"]]

sprite_links = get_sprite_links(poke_ids, api_url)
# Out:
# Processing id: 1
# Processing id: 2
# Processing id: 3
# Processing id: 4
# Processing id: 5
# Processing id: 6
# Processing id: 7
# Processing id: 8
# Processing id: 9
# Processing id: 10
# Processing id: 11
# Processing id: 12
# Processing id: 13
# Processing id: 14
# Processing id: 15
# Processing id: 16
# Processing id: 17
# Processing id: 18
# Processing id: 19
# Processing id: 20
# Processing id: 21
# Processing id: 22
# Processing id: 23
# Processing id: 24
# Processing id: 25
# Processing id: 26
# Processing id: 27
# Processing id: 28
# Processing id: 29
# Processing id: 30
# Processing id: 31
# Processing id: 32
# Processing id: 33
# Processing id: 34
# Processing id: 35
# Processing id: 36
# Processing id: 37
# Processing id: 38
# Processing id: 39
# Processing id: 40
# Processing id: 41
# Processing id: 42
# Processing id: 43
# Processing id: 44
# Processing id: 45
# Processing id: 46
# Processing id: 47
# Processing id: 48
# Processing id: 49
# Processing id: 50
# Processing id: 51
# Processing id: 52
# Processing id: 53
# Processing id: 54
# Processing id: 55
# Processing id: 56
# Processing id: 57
# Processing id: 58
# Processing id: 59
# Processing id: 60
# Processing id: 61
# Processing id: 62
# Processing id: 63
# Processing id: 64
# Processing id: 65
# Processing id: 66
# Processing id: 67
# Processing id: 68
# Processing id: 69
# Processing id: 70
# Processing id: 71
# Processing id: 72
# Processing id: 73
# Processing id: 74
# Processing id: 75
# Processing id: 76
# Processing id: 77
# Processing id: 78
# Processing id: 79
# Processing id: 80
# Processing id: 81
# Processing id: 82
# Processing id: 83
# Processing id: 84
# Processing id: 85
# Processing id: 86
# Processing id: 87
# Processing id: 88
# Processing id: 89
# Processing id: 90
# Processing id: 91
# Processing id: 92
# Processing id: 93
# Processing id: 94
# Processing id: 95
# Processing id: 96
# Processing id: 97
# Processing id: 98
# Processing id: 99
# Processing id: 100
# Processing id: 101
# Processing id: 102
# Processing id: 103
# Processing id: 104
# Processing id: 105
# Processing id: 106
# Processing id: 107
# Processing id: 108
# Processing id: 109
# Processing id: 110
# Processing id: 111
# Processing id: 112
# Processing id: 113
# Processing id: 114
# Processing id: 972
# Processing id: 973
# Processing id: 974
# Processing id: 975
# Processing id: 976
# Processing id: 977
# Processing id: 978
# Processing id: 979
# Processing id: 980
# Processing id: 981
# Processing id: 982
# Processing id: 983
# Processing id: 984
# Processing id: 985
# Processing id: 986
# Processing id: 987
# Processing id: 988
# Processing id: 989
# Processing id: 990
# Processing id: 991
# Processing id: 992
# Processing id: 993
# Processing id: 994
# Processing id: 995
# Processing id: 996
# Processing id: 997
# Processing id: 998
# Processing id: 999
# Processing id: 1000
# Processing id: 1001
# Processing id: 1002
# Processing id: 1003
# Processing id: 1004
# Processing id: 1005
# Processing id: 1006
# Processing id: 1007
# Processing id: 1008
# Processing id: 10001
# Processing id: 10002
# Processing id: 10003
# Processing id: 10004
# Processing id: 10005
# Processing id: 10006
# Processing id: 10007
# Processing id: 10008
# Processing id: 10009
# Processing id: 10010
# Processing id: 10011
# Processing id: 10012
# Processing id: 10013
# Processing id: 10014
# Processing id: 10015
# Processing id: 10016
# Processing id: 10017
# Processing id: 10018
# Processing id: 10019
# Processing id: 10020
# Processing id: 10021
# Processing id: 10022
# Processing id: 10023
# Processing id: 10024
# Processing id: 10025
# Processing id: 10026
# Processing id: 10027
# Processing id: 10028
# Processing id: 10029
# Processing id: 10030
# Processing id: 10031
# Processing id: 10032
# Processing id: 10033
# Processing id: 10034
# Processing id: 10035
# Processing id: 10036
# Processing id: 10037
# Processing id: 10038
# Processing id: 10039
# Processing id: 10040
# Processing id: 10041
# Processing id: 10042
# Processing id: 10043
# Processing id: 10044
# Processing id: 10045
# Processing id: 10046
# Processing id: 10047
# Processing id: 10048
# Processing id: 10049
# Processing id: 10050
# Processing id: 10051
# Processing id: 10052
# Processing id: 10053
# Processing id: 10054
# Processing id: 10055
# Processing id: 10056
# Processing id: 10057
# Processing id: 10058
# Processing id: 10059
# Processing id: 10060
# Processing id: 10061
# Processing id: 10062
# Processing id: 10063
# Processing id: 10064
# Processing id: 10065
# Processing id: 10066
# Processing id: 10067
# Processing id: 10068
# Processing id: 10069
# Processing id: 10070
# Processing id: 10071
# Processing id: 10072
# Processing id: 10073
# Processing id: 10074
# Processing id: 10075
# Processing id: 10076
# Processing id: 10077
# Processing id: 10078
# Processing id: 10079
# Processing id: 10080
# Processing id: 10081
# Processing id: 10082
# Processing id: 10083
# Processing id: 10084
# Processing id: 10085
# Processing id: 10086
# Processing id: 10087
# Processing id: 10088
# Processing id: 10089
# Processing id: 10090
# Processing id: 10091
# Processing id: 10092
# Processing id: 10093
# Processing id: 10094
# Processing id: 10095
# Processing id: 10096
# Processing id: 10097
# Processing id: 10098
# Processing id: 10099
# Processing id: 10100
# Processing id: 10101
# Processing id: 10102
# Processing id: 10103
# Processing id: 10104
# Processing id: 10105
# Processing id: 10106
# Processing id: 10107
# Processing id: 10108
# Processing id: 10109
# Processing id: 10110
# Processing id: 10111
# Processing id: 10112
# Processing id: 10113
# Processing id: 10114
# Processing id: 10115
# Processing id: 10116
# Processing id: 10117
# Processing id: 10118
# Processing id: 10119
# Processing id: 10120
# Processing id: 10121
# Processing id: 10122
# Processing id: 10123
# Processing id: 10124
# Processing id: 10125
# Processing id: 10126
# Processing id: 10127
# Processing id: 10128
# Processing id: 10129
# Processing id: 10130
# Processing id: 10131
# Processing id: 10132
# Processing id: 10133
# Processing id: 10134
# Processing id: 10135
# Processing id: 10136
# Processing id: 10137
# Processing id: 10138
# Processing id: 10139
# Processing id: 10140
# Processing id: 10141
# Processing id: 10142
# Processing id: 10143
# Processing id: 10144
# Processing id: 10145
# Processing id: 10146
# Processing id: 10147
# Processing id: 10148
# Processing id: 10149
# Processing id: 10150
# Processing id: 10151
# Processing id: 10152
# Processing id: 10153
# Processing id: 10154
# Processing id: 10155
# Processing id: 10156
# Processing id: 10157
# Processing id: 10158
# Processing id: 10159
# Processing id: 10160
# Processing id: 10161
# Processing id: 10162
# Processing id: 10163
# Processing id: 10164
# Processing id: 10165
# Processing id: 10166
# Processing id: 10167
# Processing id: 10168
# Processing id: 10169
# Processing id: 10170
# Processing id: 10171
# Processing id: 10172
# Processing id: 10173
# Processing id: 10174
# Processing id: 10175
# Processing id: 10176
# Processing id: 10177
# Processing id: 10178
# Processing id: 10179
# Processing id: 10180
# Processing id: 10181
# Processing id: 10182
# Processing id: 10183
# Processing id: 10184
# Processing id: 10185
# Processing id: 10186
# Processing id: 10187
# Processing id: 10188
# Processing id: 10189
# Processing id: 10190
# Processing id: 10191
# Processing id: 10192
# Processing id: 10193
# Processing id: 10194
# Processing id: 10195
# Processing id: 10196
# Processing id: 10197
# Processing id: 10198
# Processing id: 10199
# Processing id: 10200
# Processing id: 10201
# Processing id: 10202
# Processing id: 10203
# Processing id: 10204
# Processing id: 10205
# Processing id: 10206
# Processing id: 10207
# Processing id: 10208
# Processing id: 10209
# Processing id: 10210
# Processing id: 10211
# Processing id: 10212
# Processing id: 10213
# Processing id: 10214
# Processing id: 10215
# Processing id: 10216
# Processing id: 10217
# Processing id: 10218
# Processing id: 10219
# Processing id: 10220
# Processing id: 10221
# Processing id: 10222
# Processing id: 10223
# Processing id: 10224
# Processing id: 10225
# Processing id: 10226
# Processing id: 10227
# Processing id: 10228
# Processing id: 10229
# Processing id: 10230
# Processing id: 10231
# Processing id: 10232
# Processing id: 10233
# Processing id: 10234
# Processing id: 10235
# Processing id: 10236
# Processing id: 10237
# Processing id: 10238
# Processing id: 10239
# Processing id: 10240
# Processing id: 10241
# Processing id: 10242
# Processing id: 10243
# Processing id: 10244
# Processing id: 10245
# Processing id: 10246
# Processing id: 10247
# Processing id: 10248
# Processing id: 10249
# Processing id: 10250
# Processing id: 10251
# Processing id: 10252
# Processing id: 10253
# Processing id: 10254
# Processing id: 10255
# Processing id: 10256
# Processing id: 10257
# Processing id: 10258
# Processing id: 10259
# Processing id: 10260
# Processing id: 10261
# Processing id: 10262
# Processing id: 10263
# Processing id: 10264
# Processing id: 10265
# Processing id: 10266
# Processing id: 10267
# Processing id: 10268
# Processing id: 10269
# Processing id: 10270
# Processing id: 10271

# %%
def flatten_links(link_dict, id: int) -> dict[str, str]:
    flattened_links = {}
    
    for key in link_dict:
        # sprites for previous generations are nested, need to un-nest these
        curr_links = {}
        # generations have game-indexed sub-dictionaries for sprites 
        if key in generations:
            curr_links = {f"{id}_{key}_{game}_{style}": url 
                         for game in generations_to_games[key] 
                         for style, url in link_dict[key][game].items() if url}
        else:
            curr_links = {f"{id}_{key}_{style}": url 
                          for style, url in link_dict[key].items() if url}
        
        # add flattened dict to result dict
        flattened_links.update(curr_links)    
        
    return flattened_links


def gif_to_images(anim):
    return [frame.convert("RGBA").copy() for frame in ImageSequence.Iterator(anim)]


def create_mask(im: Image): 
    
    mask = im.copy()
    if mask.mode != "RGBA":
        mask = mask.convert("RGBA")

    # Get the pixel data for the image
    pixels = mask.load()

    # Iterate over each pixel in the image
    for x in range(mask.width):
        for y in range(mask.height):
            # Check if the pixel is not transparent
            if pixels[x, y][3] > 0:
                # Set the pixel value to black
                pixels[x, y] = (0, 0, 0, 255)
    
    return mask


# def create_anim_frame_mask(frame: Image):
#     mask = frame.copy()

#     for x in range(mask.width):
#         for y in range(mask.height):
#             if 


def add_background(im: Image, target_size: tuple[int, int] = (96, 96)):
    # create white background
    bg = Image.new("RGB", target_size, (255, 255, 255))
    x, y = im.size
    if x > target_size[0] or y > target_size[1]:
        print("WOOPS! target image size larger than input!")
        return None

    x_shift = (target_size[0] - x) // 2 - 1
    y_shift = (target_size[1] - y) // 2 - 1
    
    bg.paste(im, (x_shift, y_shift), im)
    return bg


def get_image(url: str) -> Image:
    image = None
    resp = requests.get(url)
    if resp.status_code == 200:
        # Read the binary data from the response
        image_data = BytesIO(resp.content)

        # Create a PIL Image object from the image data
        try:
            image = Image.open(image_data)
        except:
            image = None 

    return image


def process_and_save_images(links):
    row_list = []

    for id, data in links.items():
        
        print(f"Processing id: {id}")
        used_sprites = set()
        mask_paths = {}

        for key, url in data.items():

            im_queue = []
            path_queue = []

            if "artwork" in key:
                im = get_image(url).convert("RGBA")
                im = add_background(im, im.size)
                im_path = DATA_PATH / ARTWORK_PATH / Path(f"{key}.png")
                im.save(im_path)

            elif "animation" in key:
                
                if not save_animations: continue    

                gif = get_image(url)
                frames = gif_to_images(gif)
                for ix, frame in enumerate(frames):
                    
                    # check for new sprite
                    im_hash = str(imagehash.phash(frame))
                    if im_hash in used_sprites: continue
                    used_sprites.add(im_hash)

                    # create mask
                    mask = create_mask(frame)
                    frame, mask = add_background(frame), add_background(mask)
                    frame_path = SPRITE_PATH / Path(f"{key}_{ix}.png")
                    mask_path = MASK_PATH / Path(f"{key}_{ix}_mask.png")
                    # add image and mask to queue 
                    im_queue.append([frame, mask])
                    path_queue.append([frame_path, mask_path])
            else:
                # Bodge to solve an issue where some poke pngs have malformed identification strings
                im = get_image(url)
                if not im: continue
                im = im.convert("RGBA")

                # create mask
                mask = create_mask(im)
                im, mask = add_background(im), add_background(mask)
                if not im or not mask: continue

                # check for unique image
                im_hash = str(imagehash.phash(im))
                if im_hash in used_sprites: continue
                used_sprites.add(im_hash)

                im_path = SPRITE_PATH / Path(f"{key}.png")
                mask_path = MASK_PATH / Path(f"{key}_mask.png")

                # check for unique mask
                mask_hash = str(imagehash.phash(mask))
                if mask_hash in mask_paths.keys():
                    mask_path = mask_paths[mask_hash]
                else:
                    mask_paths[mask_hash] = mask_path

                im_queue.append([im, mask])
                path_queue.append([im_path, mask_path])
            
            # save images in im_queue to path_queue locations
            for ims, paths in zip(im_queue, path_queue):
                # save
                im, mask = ims
                im_path, mask_path = paths
                im.save(DATA_PATH / im_path)
                
                # avoid saving duplicate masks for shiny pokemon
                mask.convert("L").save(DATA_PATH / mask_path)

                # create row for csv
                row_list.append({"image": im_path.as_posix(), "mask": mask_path.as_posix(), "id": id})

        
    return pd.DataFrame(row_list)

# %%
# flatten all links
links = extract_pertinent_links(sprite_links)

flattened_links = {id: flatten_links(data, id) for id, data in links.items()}

# flattened_links[1]
# save images to disk
image_df = process_and_save_images(flattened_links)
# Out:
# Processing id: 1
# Processing id: 2
# Processing id: 3
# Processing id: 4
# Processing id: 5
# Processing id: 6
# Processing id: 7
# Processing id: 8
# Processing id: 9
# Processing id: 10
# Processing id: 11
# Processing id: 12
# Processing id: 13
# Processing id: 14
# Processing id: 15
# Processing id: 16
# Processing id: 17
# Processing id: 18
# Processing id: 19
# Processing id: 20
# Processing id: 21
# Processing id: 22
# Processing id: 23
# Processing id: 24
# Processing id: 25
# Processing id: 26
# Processing id: 27
# Processing id: 28
# Processing id: 29
# Processing id: 30
# Processing id: 31
# Processing id: 32
# Processing id: 33
# Processing id: 34
# Processing id: 35
# Processing id: 36
# Processing id: 37
# Processing id: 38
# Processing id: 39
# Processing id: 40
# Processing id: 41
# Processing id: 42
# Processing id: 43
# Processing id: 44
# Processing id: 45
# Processing id: 46
# Processing id: 47
# Processing id: 48
# Processing id: 49
# Processing id: 50
# Processing id: 51
# Processing id: 52
# Processing id: 53
# Processing id: 54
# Processing id: 55
# Processing id: 56
# Processing id: 57
# Processing id: 58
# Processing id: 59
# Processing id: 60
# Processing id: 61
# Processing id: 62
# Processing id: 63
# Processing id: 64
# Processing id: 65
# Processing id: 66
# Processing id: 67
# Processing id: 68
# Processing id: 69
# Processing id: 70
# Processing id: 71
# Processing id: 72
# Processing id: 73
# Processing id: 74
# Processing id: 75
# Processing id: 76
# Processing id: 77
# Processing id: 78
# Processing id: 79
# Processing id: 80
# Processing id: 81
# Processing id: 82
# Processing id: 83
# Processing id: 84
# Processing id: 85
# Processing id: 86
# Processing id: 87
# Processing id: 88
# Processing id: 89
# Processing id: 90
# Processing id: 91
# Processing id: 92
# Processing id: 93
# Processing id: 94
# Processing id: 95
# Processing id: 96
# Processing id: 97
# Processing id: 98
# Processing id: 99
# Processing id: 100
# Processing id: 101
# Processing id: 102
# Processing id: 103
# Processing id: 104
# Processing id: 105
# Processing id: 106
# Processing id: 107
# Processing id: 108
# Processing id: 109
# Processing id: 110
# Processing id: 111
# Processing id: 112
# Processing id: 113
# Processing id: 114
# Processing id: 115
# Processing id: 116
# Processing id: 117
# Processing id: 118
# Processing id: 119
# Processing id: 120
# Processing id: 121
# Processing id: 122
# Processing id: 988
# Processing id: 989
# Processing id: 990
# Processing id: 991
# Processing id: 992
# Processing id: 993
# Processing id: 994
# Processing id: 995
# Processing id: 996
# Processing id: 997
# Processing id: 998
# Processing id: 999
# Processing id: 1000
# Processing id: 1001
# Processing id: 1002
# Processing id: 1003
# Processing id: 1004
# Processing id: 1005
# Processing id: 1006
# Processing id: 1007
# Processing id: 1008
# Processing id: 10001
# Processing id: 10002
# Processing id: 10003
# Processing id: 10004
# Processing id: 10005
# Processing id: 10006
# Processing id: 10007
# Processing id: 10008
# Processing id: 10009
# Processing id: 10010
# Processing id: 10011
# Processing id: 10012
# Processing id: 10013
# Processing id: 10014
# Processing id: 10015
# Processing id: 10016
# Processing id: 10017
# Processing id: 10018
# Processing id: 10019
# Processing id: 10020
# Processing id: 10021
# Processing id: 10022
# Processing id: 10023
# Processing id: 10024
# Processing id: 10025
# Processing id: 10026
# Processing id: 10027
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10028
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10029
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10030
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10031
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10032
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10033
# Processing id: 10034
# Processing id: 10035
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10036
# Processing id: 10037
# Processing id: 10038
# Processing id: 10039
# Processing id: 10040
# Processing id: 10041
# Processing id: 10042
# Processing id: 10043
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10044
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10045
# Processing id: 10046
# Processing id: 10047
# Processing id: 10048
# Processing id: 10049
# Processing id: 10050
# Processing id: 10051
# Processing id: 10052
# Processing id: 10053
# Processing id: 10054
# Processing id: 10055
# Processing id: 10056
# Processing id: 10057
# Processing id: 10058
# Processing id: 10059
# Processing id: 10060
# Processing id: 10061
# Processing id: 10062
# Processing id: 10063
# Processing id: 10064
# Processing id: 10065
# Processing id: 10066
# Processing id: 10067
# Processing id: 10068
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10069
# Processing id: 10070
# Processing id: 10071
# Processing id: 10072
# Processing id: 10073
# Processing id: 10074
# Processing id: 10075
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10076
# Processing id: 10077
# Processing id: 10078
# Processing id: 10079
# Processing id: 10080
# Processing id: 10081
# Processing id: 10082
# Processing id: 10083
# Processing id: 10084
# Processing id: 10085
# Processing id: 10086
# Processing id: 10087
# Processing id: 10088
# Processing id: 10089
# Processing id: 10090
# Processing id: 10091
# Processing id: 10092
# Processing id: 10093
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10094
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10095
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10096
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10097
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10098
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10099
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10100
# Processing id: 10101
# Processing id: 10102
# Processing id: 10103
# Processing id: 10104
# Processing id: 10105
# Processing id: 10106
# Processing id: 10107
# Processing id: 10108
# Processing id: 10109
# Processing id: 10110
# Processing id: 10111
# Processing id: 10112
# Processing id: 10113
# Processing id: 10114
# Processing id: 10115
# Processing id: 10116
# Processing id: 10117
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10118
# Processing id: 10119
# Processing id: 10120
# Processing id: 10121
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10122
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10123
# Processing id: 10124
# Processing id: 10125
# Processing id: 10126
# Processing id: 10127
# Processing id: 10128
# Processing id: 10129
# Processing id: 10130
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10131
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10132
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10133
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10134
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10135
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10136
# Processing id: 10137
# Processing id: 10138
# Processing id: 10139
# Processing id: 10140
# Processing id: 10141
# Processing id: 10142
# Processing id: 10143
# Processing id: 10144
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10145
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10146
# Processing id: 10147
# Processing id: 10148
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10149
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10150
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10151
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10152
# Processing id: 10153
# Processing id: 10154
# Processing id: 10155
# Processing id: 10156
# Processing id: 10157
# Processing id: 10158
# Processing id: 10159
# Processing id: 10160
# Processing id: 10161
# Processing id: 10162
# Processing id: 10163
# Processing id: 10164
# Processing id: 10165
# Processing id: 10166
# Processing id: 10167
# Processing id: 10168
# Processing id: 10169
# Processing id: 10170
# Processing id: 10171
# Processing id: 10172
# Processing id: 10173
# Processing id: 10174
# Processing id: 10175
# Processing id: 10176
# Processing id: 10177
# Processing id: 10178
# Processing id: 10179
# Processing id: 10180
# Processing id: 10181
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# WOOPS! target image size larger than input!
# Processing id: 10182
# Processing id: 10183
# Processing id: 10184
# Processing id: 10185
# Processing id: 10186
# Processing id: 10187
# Processing id: 10188
# Processing id: 10189
# Processing id: 10190
# Processing id: 10191
# Processing id: 10192
# Processing id: 10193
# Processing id: 10194
# Processing id: 10195
# Processing id: 10196
# Processing id: 10197
# Processing id: 10198
# Processing id: 10199
# Processing id: 10200
# Processing id: 10201
# Processing id: 10202
# Processing id: 10203
# Processing id: 10204
# Processing id: 10205
# Processing id: 10206
# Processing id: 10207
# Processing id: 10208
# Processing id: 10209
# Processing id: 10210
# Processing id: 10211
# Processing id: 10212
# Processing id: 10213
# Processing id: 10214
# Processing id: 10215
# Processing id: 10216
# Processing id: 10217
# Processing id: 10218
# Processing id: 10219
# Processing id: 10220
# Processing id: 10221
# Processing id: 10222
# Processing id: 10223
# Processing id: 10224
# Processing id: 10225
# Processing id: 10226
# Processing id: 10227
# Processing id: 10228
# Processing id: 10229
# Processing id: 10230
# Processing id: 10231
# Processing id: 10232
# Processing id: 10233
# Processing id: 10234
# Processing id: 10235
# Processing id: 10236
# Processing id: 10237
# Processing id: 10238
# Processing id: 10239
# Processing id: 10240
# Processing id: 10241
# Processing id: 10242
# Processing id: 10243
# Processing id: 10244
# Processing id: 10245
# Processing id: 10246
# Processing id: 10247
# Processing id: 10248
# Processing id: 10249
# Processing id: 10250
# Processing id: 10251
# Processing id: 10252
# Processing id: 10253
# Processing id: 10254
# Processing id: 10255
# Processing id: 10256
# Processing id: 10257
# Processing id: 10258
# Processing id: 10259
# Processing id: 10260
# Processing id: 10261
# Processing id: 10262
# Processing id: 10263
# Processing id: 10264
# Processing id: 10265
# Processing id: 10266
# Processing id: 10267
# Processing id: 10268
# Processing id: 10269
# Processing id: 10270
# Processing id: 10271

# %%
image_df.shape
# Out:
# (5001, 3)

# %%
# create dataframe for a pytorch dataset
cols_to_keep = ["id", "type_1", "type_2", "is_legendary", "is_mythical", "generation", "egg_group_0", "egg_group_1"]
filtered_poke_df = poke_df[cols_to_keep]
final_df = image_df.merge(filtered_poke_df, on="id", how="left")
final_df.shape
# Out:
# (5001, 10)

# %%
# write to a csv to be used in a dataset
final_df.to_csv(DATALOADER_CSV_PATH, index=False)

# %%
# create CSV for mask dataset
mask_csv_path = "masks.csv"
mask_df = final_df[["mask"]].drop_duplicates()
print(f"Mask df shape: {mask_df.shape}")

mask_df.to_csv(DATA_PATH / Path(mask_csv_path), index=False)
# Out:
# Mask df shape: (2784, 1)
